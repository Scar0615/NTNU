# %% [markdown]
# <h1 align="center">LineBot based on Flask</h1>

# %% [markdown]
# <hr>
# <h3>LINE Messaging API SDK for Python</h3>
# <img src="https://developers.line.biz/assets/img/messaging-api-architecture.f40bffbb.png">
# <p style="text-align:center">
# 官方使用說明<br>
# <a href="https://developers.line.biz/en/docs/messaging-api/overview/">
# https://developers.line.biz/en/docs/messaging-api/overview/
# </a><br>
# （上圖取自官網說明）
# </p>

# %% [markdown]
# <hr>
# <h3>line-bot-sdk 安裝</h3>
# <pre>
# <strong style="color:red">pip install line-bot-sdk</strong>
# （conda install 無法安裝）
# 建議建立虛擬環境，在環境中安裝 line-bot-sdk, jieba, flask, ...
# 官方使用說明（含範例）
# <a href="https://pypi.org/project/line-bot-sdk/">https://pypi.org/project/line-bot-sdk/</a>
# </pre>

# %% [markdown]
# <hr>
# <h3>安裝後測試</h3>

# %%
import linebot
print(linebot.__version__)

# %% [markdown]
# <hr>
# <h3>GitHub - LINE Messaging API SDK for Python</h3>
# <pre>
# GitHub 範例（各種功能範例，非常完整）
# <a href="https://github.com/line/line-bot-sdk-python">https://github.com/line/line-bot-sdk-python</a>
# </pre>

# %% [markdown]
# <hr>
# <h3>文字傳送訊息（TextSendMessage）發送測試</h3>
# <pre>
# 必備資訊：
# 1. <strong style="color:red">Channel Secret</strong>
# 2. <strong style="color:red">Channel Access Token</strong>
# 3. <strong style="color:red">User ID</strong>（發給自己）
# </pre>
# <p>
# <strong style="color:magenta">先加入此 Channel (Bot) 為好友</strong>，否則，你會收不到此訊息，除非你知道朋友 Line 的 User ID
# </p>

# %%
# 文字傳送訊息（TextSendMessage）發送測試

# 載入 linebot 工具模組
from linebot import LineBotApi
from linebot.models import TextSendMessage

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='

# 產生 bot 物件
bot = LineBotApi(token)

# 設定接收者（User ID）
# 記得修改成自己的 ID！記得修改成自己的 ID！記得修改成自己的 ID！
# 很重要所以說三次！
uid = 'Ud255d7207bec55255b620ab4953743d5'
# 設定文字訊息內容
txt = 'Hello from Anaconda'
# 建立傳送文字訊息
msg = TextSendMessage(text=txt)

# 訊息發出
bot.push_message(uid, msg)

# %% [markdown]
# <hr>
# <h3>圖片傳送訊息（ImageSendMessage）發送測試</h3>
# <pre>
# 必備資訊：
# 1. <strong style="color:red">Channel Secret</strong>
# 2. <strong style="color:red">Channel Access Token</strong>
# 3. <strong style="color:red">User ID</strong>（發給自己）
# </pre>
# <img src="https://etech.gac.ntnu.edu.tw/bot/images/ai.png" width="320">
# <p style="text-align:center">圖片來源必須是經過 CA 認證伺服器的網址：
#     <a href="https://etech.gac.ntnu.edu.tw/bot/images/ai.png">https://etech.gac.ntnu.edu.tw/bot/images/ai.png</a>
# </p>
# <hr>
# <pre>
# 圖片必須放置在預先準備好『<span style="color:red">通過認證的網站伺服器</span>』，
# 如果要動態變更圖片內容的話，
# 可以利用 PHP, Python, ... 動態產生圖片檔案，放置於網站上，
# 在 LINE 的圖片傳送訊息中傳送網址（URL）給對方。
# 圖片原則上為一張原始圖，一張預覽圖（二者相同也可以，速度稍慢）。
# </pre>

# %%
# 圖片傳送訊息（ImageSendMessage）發送測試

# 載入 linebot 工具模組
from linebot import LineBotApi
from linebot.models import ImageSendMessage

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='

# 產生 bot 物件
bot = LineBotApi(token)

# 設定接收者（User ID）
uid = 'Ud255d7207bec55255b620ab4953743d5'
# 設定文字訊息內容
txt = 'Hello from Anaconda'
# 建立圖片傳送訊息
msg = ImageSendMessage(
    original_content_url='https://etech.gac.ntnu.edu.tw/bot/images/ai.png',
    preview_image_url='https://etech.gac.ntnu.edu.tw/bot/images/ai.png'
)

# 訊息發出
bot.push_message(uid, msg)

# %% [markdown]
# <hr>
# <h3>Flex 傳送訊息（FlexSendMessage）發送測試</h3>
# <pre>
# 必備資訊：
# 1. <strong style="color:red">Channel Secret</strong>
# 2. <strong style="color:red">Channel Access Token</strong>
# 3. <strong style="color:red">User ID</strong>（發給自己）
# </pre>
# <img src="https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg" width="480">
# <p style="text-align:center">圖片來源必須是經過 CA 認證伺服器的網址：
#     <a href="https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg">https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg</a>
# </p>
# <hr>
# <pre>
# Flex 是新提供可自訂的組合式訊息，可以在訊息中包含影像、文字、按鈕、、、
# BubbleContainer 用來排版
# ImageComponent 用來放置圖片
# TextComponent 用來放置文字
# ButtonComponent 是有超連結功能的按鈕
# URIAction 是超連結物件，用來指定物件點擊後的去處
# ......
# </pre>

# %%
# Flex 傳送訊息（FlexSendMessage）發送測試

# 載入 linebot 工具模組
from linebot import LineBotApi
from linebot.models import (
    BubbleContainer,
    ImageComponent,
    URIAction,
    BoxComponent,
    TextComponent,
    ButtonComponent,
    FlexSendMessage
)

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='

# 產生 bot 物件
bot = LineBotApi(token)

# 設定接收者（User ID）
uid = 'Ud255d7207bec55255b620ab4953743d5'
# 設定文字訊息內容
txt = 'Hello from Anaconda'
# 建立 Flex 傳送訊息
bubble = BubbleContainer(
    direction = 'ltr',
    hero = ImageComponent(
        url='https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg',
        size='full',
        aspect_ratio='4:3', # one of 1:1, 2:1, 3:1, 16:9, 4:3, ...
        aspect_mode='fit', # cover, fit
        action=URIAction(uri='https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg', label='Flex')
    ),
    body = BoxComponent(
        layout='vertical',
        contents=[
            TextComponent(text='Flex 的標題', weight='bold'),
            TextComponent(text='Flex 內的文字內容（第一列）'),
            TextComponent(text='Flex 內的文字內容（第二列）'),
            TextComponent(text='......（第三列）'),
            ButtonComponent(
                style='link',
                height='sm',
                action=URIAction(label='按這裡去 Google', uri='http://www.google.com.tw/')
            ),
            ButtonComponent(
                style='link',
                height='sm',
                action=URIAction(label='按這裡看地圖', uri='https://www.google.com.tw/maps')
            )
        ]
    )
)
flx = FlexSendMessage(alt_text='This is my flex message...', contents=bubble)

# 訊息發出
bot.push_message(uid, flx)

# %% [markdown]
# <hr>
# <h3>請參考 Messaging API 官方文件，有非常多類型訊息可以使用</h3>
# <p>
#     <a href="https://developers.line.biz/en/docs/messaging-api/overview/">
#         https://developers.line.biz/en/docs/messaging-api/overview/
#     </a>
# </p>
# <pre style="color:blue">
# Text message
# Sticker message
# Image message
# Video message
# Audio message
# Location message
# Imagemap message
# Template message
# Flex Message
# </pre>

# %% [markdown]
# <hr>
# <h3>官方說明所提供 LineBot ECHO 範例（使用 Flask 提供服務）</h3>
# <pre>
# Flask 預設 Port No. 5000
# 利用 ngrok 進行內網穿越
# <span style="color:red">ngrok.exe http http://127.0.0.1:5000</span>（使用完整網址以避免 localhost 名稱被禁用）
# Line Developers 裡的 Channel Webhook URL 設為 <span style="color:red">https://???????.ngrok.io/callback</span>
# 將 Line Server 封包由 https://https://???????.ngrok.io/callback 轉送至內網的 http://localhost:5000/
# <span style="color:magenta">測試OK！</span>
# （Channel 裡的 Webhook URL Verify 會失敗，據了解是 SDK 的很早期就留下來的 Bug，至今尚未修復）
# </pre>

# %%
# 官方說明提供 LineBot 範例（使用 Flask提供服務）

from flask import Flask, request, abort

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)

app = Flask(__name__)

# line_bot_api = LineBotApi('YOUR_CHANNEL_ACCESS_TOKEN')
# handler = WebhookHandler('YOUR_CHANNEL_SECRET')

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='
line_bot_api = LineBotApi(token)
handler = WebhookHandler(secret)

@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=event.message.text))

if __name__ == "__main__":
    app.run()

# %% [markdown]
# <hr>
# <h3>取得 Line 好友的基本訊息</h3>

# %%
# 取得 Line 好友的基本訊息

from flask import Flask, request, abort

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)

app = Flask(__name__)

# line_bot_api = LineBotApi('YOUR_CHANNEL_ACCESS_TOKEN')
# handler = WebhookHandler('YOUR_CHANNEL_SECRET')

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='
line_bot_api = LineBotApi(token)
handler = WebhookHandler(secret)

@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=event.message.text))
    # 檢視訊息內容
    print(event)
    msg = event.message.text
    uid = event.source.user_id
    print('msg = ', msg)
    print('uid = ', uid)
    # 取得並顯示傳訊者基本資料
    profile = line_bot_api.get_profile(uid)
    print('使用者名稱：', profile.display_name)
    print('UserID：', profile.user_id)
    print('圖片 URL：', profile.picture_url)
    print('狀態訊息：', profile.status_message)

if __name__ == "__main__":
    app.run()

# %% [markdown]
# <hr>
# <h3 style="color:orange">LineBot（整合版）</h3>
# <pre>
# 以關鍵字比對進行簡單套句式對話
# 回應 ECHO 或發送 FlexSendMessage
# </pre>

# %%
# LineBot（整合版）

#載入各種工具模組與元件
from flask import Flask, request, abort

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)
from linebot.models import (
    BubbleContainer,
    ImageComponent,
    URIAction,
    BoxComponent,
    TextComponent,
    ButtonComponent,
    FlexSendMessage
)

# 建立 Flask 應用
app = Flask(__name__)

# line_bot_api = LineBotApi('YOUR_CHANNEL_ACCESS_TOKEN')
# handler = WebhookHandler('YOUR_CHANNEL_SECRET')

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c9aa514a666e4c482dc87b33599e4b95'
token = \
'aOpZRZzuB87MiXEiLodo626ip9ja2lIZS5TGn6GlkWSP9tuOZyO30oS+KGsNkU/bVBUrkZOBAjR6d7XbWV6KjOM82NaxVOO8Z4CCv1OXWf2oq1B9B88uJratZ+Zzud6mUXtG5x3PAOKt38hK1OA9wgdB04t89/1O/w1cDnyilFU='
line_bot_api = LineBotApi(token)
handler = WebhookHandler(secret)

# 網站路徑
@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

# 加入文字訊息處理程序
@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    bot_reply(event)

# 訊息回覆函數定義
def bot_reply(event):
    try:
        msg = event.message.text
        if ('flex' in msg):
            uid = event.source.user_id
            # 建立 Flex 傳送訊息
            bubble = BubbleContainer(
                direction = 'ltr',
                hero = ImageComponent(
                    url='https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg',
                    size='full',
                    aspect_ratio='4:3', # one of 1:1, 2:1, 3:1, 16:9, 4:3, ...
                    aspect_mode='fit', # cover, fit
                    action=URIAction(uri='https://etech.gac.ntnu.edu.tw/bot/images/flower.jpg', label='Flex')
                ),
                body = BoxComponent(
                    layout='vertical',
                    contents=[
                        TextComponent(text='Flex 的標題', weight='bold'),
                        TextComponent(text='Flex 內的文字內容（第一列）'),
                        TextComponent(text='Flex 內的文字內容（第二列）'),
                        TextComponent(text='......（第三列）'),
                        ButtonComponent(
                            style='link',
                            height='sm',
                            action=URIAction(label='按這裡去 Google', uri='http://www.google.com.tw/')
                        ),
                        ButtonComponent(
                            style='link',
                            height='sm',
                            action=URIAction(label='按這裡看地圖', uri='https://www.google.com.tw/maps')
                        )
                    ]
                )
            )
            flx = FlexSendMessage(alt_text='This is my flex message...', contents=bubble)
            line_bot_api.push_message(uid, flx)
        else:
            line_bot_api.reply_message(
                event.reply_token,
                TextSendMessage(text=event.message.text))
    except:
        line_bot_api.reply_message(
            event.reply_token,
            TextSendMessage(text='喔喔、、、有問題了！'))
    return

# 啟動 Flask 服務
if __name__ == "__main__":
    app.run()
