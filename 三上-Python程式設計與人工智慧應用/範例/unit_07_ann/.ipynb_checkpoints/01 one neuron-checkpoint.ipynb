# %% [markdown]
# <h1 align="center">One Neuron Network</h1>

# %% [markdown]
# <hr>
# <h3>Training sample</h3>
# <p>2-dimensional random samples generated by numpy</p>

# %% [markdown]
# <hr>
# <h3>Ploting scatter data of 2-classes</h3>
# <p>由 numpy 工具模組產生兩組（兩個類別）隨機數據，normal 可以指定 mean（平均值）與 std（標準差）的<strong style="color:orange">常態分佈</strong>隨機亂數</p>

# %%
# matplotlib 第一張圖常常不能顯示，所以先產生一張，當作啟動，讓後續真正需要的圖表能正常顯示
import matplotlib.pyplot as plt
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N1 = 300
N2 = 300
N = N1 + N2

# Class 1
x1 = np.random.normal(2.0, 0.5, N1)
y1 = np.random.normal(2.0, 0.5, N1)
# Class 2
x2 = np.random.normal(4.0, 0.5, N2)
y2 = np.random.normal(3.0, 0.5, N2)

plt.scatter(x1, y1, c='red')
plt.scatter(x2, y2, c='green')

plt.show()

# %% [markdown]
# <hr>
# <h3>Neuron Definition in PyTorch</h3>

# %%
import torch.nn as nn

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # 2 inputs -> 1 output
        self.fc = nn.Linear(2, 1)
    def forward(self, x):
        x = self.fc(x).sigmoid()
        return x

net = Net()

print(net)
# Out:
# Net(
#   (fc): Linear(in_features=2, out_features=1, bias=True)
# )

# %% [markdown]
# <hr>
# <h3>All parameters to be determined (2 for weights and 1 for bias)</h3>

# %%
params = list(net.parameters())
print(params)
# Out:
# [Parameter containing:
# tensor([[0.4495, 0.0333]], requires_grad=True), Parameter containing:
# tensor([-0.5920], requires_grad=True)]

# %% [markdown]
# <hr>
# <h3>Training Phase</h3>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

EPOCH = 10000

# preparing training samples

x = torch.randn(N, 2)
y = torch.randn(N, 1)
for i in range(N1):
    x[i,0] = x1[i]
    x[i,1] = y1[i]
    y[i] = 0
for i in range(N1, N1+N2):
    x[i,0] = x2[i-N1]
    x[i,1] = y2[i-N1]
    y[i] = 1

# shuffling

idx = [i for i in range(N)]
idx = np.random.permutation(idx)
x0 = x
y0 = y
for i in range(N):
    x[i] = x0[idx[i]]
    y[i] = y0[idx[i]]

# Loss function
criterion = nn.MSELoss()
# Optimizer
# optimizer = optim.SGD(net.parameters(), lr=0.01)
optimizer = optim.Adam(net.parameters(), lr=0.01)

# training
for epoch in range(EPOCH):
    # zero the gradient buffers
    optimizer.zero_grad()
    # feed foreward
    output = net(x)
    # evaluating loss
    loss = criterion(output, y)
    # display loss
    if (epoch % 100 == 0):
        print('epoch = %6d, loss = %12.8f' % (epoch, loss))
    # feed backward
    loss.backward()
    # update parameters
    optimizer.step()
# Out:
# epoch =      0, loss =   0.13947539
# epoch =    100, loss =   0.09837040
# epoch =    200, loss =   0.07826406
# epoch =    300, loss =   0.06368837
# epoch =    400, loss =   0.05309528
# epoch =    500, loss =   0.04530928
# epoch =    600, loss =   0.03946112
# epoch =    700, loss =   0.03496388
# epoch =    800, loss =   0.03142750
# epoch =    900, loss =   0.02859018
# epoch =   1000, loss =   0.02627305
# epoch =   1100, loss =   0.02435105
# epoch =   1200, loss =   0.02273496
# epoch =   1300, loss =   0.02135974
# epoch =   1400, loss =   0.02017713
# epoch =   1500, loss =   0.01915062
# epoch =   1600, loss =   0.01825220
# epoch =   1700, loss =   0.01746006
# epoch =   1800, loss =   0.01675694
h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 測試樣本
x3 = [2.0] # 測試點 X 座標
y3 = [3.0] # 測試點 Y 座標

# 繪製樣本圖
plt.scatter(x1, y1, c='red')
plt.scatter(x2, y2, c='green')
plt.scatter(x3, y3, c='cyan')
plt.show()

# 準備測試樣本，轉變格式成為 Tensor
x = torch.Tensor([x3[0],y3[0]])

# 測試（feed foreward）
output = net(x)

# 由輸出 Tensor 取出結果
v = output.tolist()[0]

# 顯示結果
print('v = ', v)
if (v <= 0.5):
    print('0: red')
else:
    print('1: green')
# Out:
# v =  0.0006729005835950375
# 0: red

# %% [markdown]
# <hr>
# <h3>Testing all training samples</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = torch.randn(N, 2)
y = torch.randn(N, 1)

# 準備整批樣本（Class 1）
for i in range(N1):
    # 準備測試樣本，轉變格式成為 Tensor
    x[i] = torch.Tensor([x1[i],y1[i]])  
# 整批測試（feed foreward）
output = net(x)
# 由輸出 Tensor 取出結果
lst1 = output.tolist()

# 準備整批樣本（Class 2）
for i in range(N2):
    # 準備測試樣本，轉變格式成為 Tensor
    x[i] = torch.Tensor([x2[i],y2[i]])  
# 整批測試（feed foreward）
output = net(x)
# 由輸出 Tensor 取出結果
lst2 = output.tolist()

# 顯示結果

x3 = []
y3 = []

correct = 0
for i in range(N1):
    v = lst1[i][0]
    if (v <= 0.5):
        correct = correct + 1
    else:
        x3.append(x1[i])
        y3.append(y1[i])
for i in range(N2):
    v = lst2[i][0]
    if (v > 0.5):
        correct = correct + 1
    else:
        x3.append(x2[i])
        y3.append(y2[i])
        
print('Recognition Rate = %d / %d' % (correct, N1+N2))

# 繪製樣本圖
plt.scatter(x1, y1, c='red')
plt.scatter(x2, y2, c='green')
plt.scatter(x3, y3, c='cyan')
plt.show()
# Out:
# Recognition Rate = 590 / 600

# %% [markdown]
# <hr>
# <h3>Testing all other samples</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 利用相同的隨機分布，重新產生一組整批測試用的樣本

N1 = 300
N2 = 300
N = N1 + N2

# Class 1
x1 = np.random.normal(2.0, 0.5, N1)
y1 = np.random.normal(2.0, 0.5, N1)
# Class 2
x2 = np.random.normal(4.0, 0.5, N2)
y2 = np.random.normal(3.0, 0.5, N2)

x = torch.randn(N, 2)
y = torch.randn(N, 1)

# 準備整批樣本（Class 1）
for i in range(N1):
    # 準備測試樣本，轉變格式成為 Tensor
    x[i] = torch.Tensor([x1[i],y1[i]])  
# 整批測試（feed foreward）
output = net(x)
# 由輸出 Tensor 取出結果
lst1 = output.tolist()

# 準備整批樣本（Class 2）
for i in range(N2):
    # 準備測試樣本，轉變格式成為 Tensor
    x[i] = torch.Tensor([x2[i],y2[i]])  
# 整批測試（feed foreward）
output = net(x)
# 由輸出 Tensor 取出結果
lst2 = output.tolist()

# 顯示結果

x3 = []
y3 = []

correct = 0
for i in range(N1):
    v = lst1[i][0]
    if (v <= 0.5):
        correct = correct + 1
    else:
        x3.append(x1[i])
        y3.append(y1[i])
for i in range(N2):
    v = lst2[i][0]
    if (v > 0.5):
        correct = correct + 1
    else:
        x3.append(x2[i])
        y3.append(y2[i])
        
print('Recognition Rate = %d / %d' % (correct, N1+N2))

# 繪製樣本圖
plt.scatter(x1, y1, c='red')
plt.scatter(x2, y2, c='green')
plt.scatter(x3, y3, c='cyan')
plt.show()
# Out:
# Recognition Rate = 590 / 600
